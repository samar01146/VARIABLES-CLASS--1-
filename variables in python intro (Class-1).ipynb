# %%
d = True

# %%
type(d)
# Out:
# bool

# %%
d
# Out:
# True

# %%
e = False

# %%
e
# Out:
# False

# %%
type(e)
# Out:
# bool

# %%
True - False
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
True - True
# Out:
# 0

# %%
True / True
# Out:
# 1.0

# %%
False / True
# Out:
# 0.0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
n = 5+7j

# %%
type(n)
# Out:
# complex

# %%
n+n
# Out:
# (10+14j)

# %%
type(n+n)
# Out:
# complex

# %%
n
# Out:
# (5+7j)

# %%
0/1
# Out:
# 0.0

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
n.real
# Out:
# 5.0

# %%
n.imag
# Out:
# 7.0

# %%
n.conjugate
# Out:
# <function complex.conjugate>

# %%
{b = "this is my first class of python and today's date is 14th may 2022"}

# %%
type(b)
# Out:
# str

# %%
I =[3,4,5,6,"sudh" , True ,5+3j , 345.456]

# %%
type(I)
# Out:
# list

# %%
I.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
I.insert
# Out:
# <function list.insert(index, object, /)>

# %%
I.remove
# Out:
# <function list.remove(value, /)>

# %%
type(I)
# Out:
# list

# %%
1(I)
# Out:
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# C:\Users\admin\AppData\Local\Temp\ipykernel_2908\2432710674.py:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   1(I)
# C:\Users\admin\AppData\Local\Temp\ipykernel_2908\2432710674.py:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   1(I)
# C:\Users\admin\AppData\Local\Temp\ipykernel_2908\2432710674.py:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   1(I)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 1(I)
#
# TypeError: 'int' object is not callable

# %%
I.count
# Out:
# <function list.count(value, /)>

# %%
t = (324,456,789,65,456,46,45464564,"sudh")

# %%
type(t)
# Out:
# tuple

# %%
t.index
# Out:
# <function tuple.index(value, start=0, stop=9223372036854775807, /)>

# %%
t.count
# Out:
# <function tuple.count(value, /)>

# %%
d = {'a': "sudh" , "b" : "kumar" , "c" :23432}

# %%
type(d)
# Out:
# dict

# %%
e = {'a': "samar", "b": "singh", "c" :72627}

# %%
type(d)
# Out:
# dict

# %%
f = (2231, 231, 432, 98, 767, "x" ,"abc")

# %%
type(f)
# Out:
# tuple

# %%
d = [45]

# %%
type(d)
# Out:
# list

# %%
s = ["hi", 5, 4.08, 2,2j]

# %%
s.pop
# Out:
# <function list.pop(index=-1, /)>

# %%
s.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
sudh = 10

# %%
sudh-2
# Out:
# 8

# %%
type(sudh)
# Out:
# int

# %%
a=34.09

# %%
type(a)
# Out:
# float

# %%
b="this is my first class of python and today's date is 14th may 2022"

# %%
type(b)
# Out:
# str

# %%
c="jsjhshbhhdhhd jsjhs shshhs"

# %%
type(c)
# Out:
# str
